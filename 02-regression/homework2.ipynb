# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
df = pd.read_csv(" https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv")

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')

# %%
median_hp = df['horsepower'].median()

# %%
median_hp
# Out:
# np.float64(149.0)

# %%
df = df.dropna(subset=['fuel_efficiency_mpg'])

# %%
train_mean = train.copy()
val_mean = val.copy()

# %%
mean_hp = train_mean['horsepower'].mean()
train_mean['horsepower'] = train_mean['horsepower'].fillna(mean_hp)
val_mean['horsepower'] = val_mean['horsepower'].fillna(mean_hp)

# %%
X_train = train_mean.drop('fuel_efficiency_mpg', axis=1)
y_train = train_mean['fuel_efficiency_mpg']
X_val = val_mean.drop('fuel_efficiency_mpg', axis=1)
y_val = val_mean['fuel_efficiency_mpg']

# %%
model_mean = LinearRegression()
model_mean.fit(X_train, y_train)
pred_mean = model_mean.predict(X_val)
rmse_mean = mean_squared_error(y_val, pred_mean, squared=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12652/1905694661.py in ?()
#       1 model_mean = LinearRegression()
# ----> 2 model_mean.fit(X_train, y_train)
#       3 pred_mean = model_mean.predict(X_val)
#       4 rmse_mean = mean_squared_error(y_val, pred_mean, squared=False)
#
# ~/.local/lib/python3.12/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1359                 skip_parameter_validation=(
#    1360                     prefer_skip_nested_validation or global_skip_validation
#    1361                 )
#    1362             ):
# -> 1363                 return fit_method(estimator, *args, **kwargs)
#
# ~/.local/lib/python3.12/site-packages/sklearn/linear_model/_base.py in ?(self, X, y, sample_weight)
#     614         n_jobs_ = self.n_jobs
#     615
# ...
